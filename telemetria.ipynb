# %% [markdown]
# # Sistema de Telemetria de Foguete 🚀

# %%
temp_interna = 22
temp_externa = 18
integridade = 1
energia = 85
pressao = 320
status_modulos = "OK"

# %%
if (15 <= temp_interna <= 30 and
    -20 <= temp_externa <= 40 and
    integridade == 1 and
    energia >= 70 and
    300 <= pressao <= 350 and
    status_modulos == "OK"):

    print("PRONTO PARA DECOLAR 🚀")
else:
    print("DECOLAGEM ABORTADA ❌")
# Out:
# PRONTO PARA DECOLAR 🚀
